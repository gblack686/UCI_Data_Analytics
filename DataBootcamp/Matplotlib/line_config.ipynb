# %%
# https://stackoverflow.com/questions/43027980/purpose-of-matplotlib-inline/43028034
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x_axis = np.arange(0,10,.1)
sin = np.sin(x_axis)
cos = np.cos(x_axis)

# %%
plt.hlines(0,0,10,alpha = .25)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sine_handle, = plt.plot(x_axis,sin,marker = 'o', color = 'blue', label = 'sin')
cos_handle, = plt.plot(x_axis,cos,marker = 'v', color = 'red', label = 'cos')

# %%
plt.legend(loc = "upper right")
