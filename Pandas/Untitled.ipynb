# %%
import os
import pandas as pd
import csv

# %%
file = ("Inland_Empire_Request.csv")
iedata = pd.read_csv(file)
iedata.head()
# Out:
#                       Project Name                 Builder Name  \
# 0     Signature at PGA West/Villas  California West Communities
# 1     Signature at PGA West/Villas  California West Communities
# 2     Signature at PGA West/Villas  California West Communities
# 3     Signature at PGA West/Villas  California West Communities
# 4  Signature at PGA West/Haciendas  California West Communities
#
#   Parent Builder          Status State     County       City  Zip Code  \
# 0            NaN  ACTIVE PROJECT    CA  Riverside  La Quinta   92253.0
# 1            NaN  ACTIVE PROJECT    CA  Riverside  La Quinta   92253.0
# 2            NaN  ACTIVE PROJECT    CA  Riverside  La Quinta   92253.0
# 3            NaN  ACTIVE PROJECT    CA  Riverside  La Quinta   92253.0
# 4            NaN  ACTIVE PROJECT    CA  Riverside  La Quinta   92253.0
#
#   Master Plan Product Type    ...                      Characteristics  \
# 0         NaN     Attached    ...      Townhomes; Temporarily Sold Out
# ...

# %%
# Out:
# <bound method Series.unique of 0       Signature at PGA West/Villas California West C...
# 1       Signature at PGA West/Villas California West C...
# 2       Signature at PGA West/Villas California West C...
# 3       Signature at PGA West/Villas California West C...
# 4       Signature at PGA West/Haciendas California Wes...
# 5       Signature at PGA West/Haciendas California Wes...
# 6       Signature at PGA West/Haciendas California Wes...
# 7       Signature at PGA West/Haciendas California Wes...
# 8       Signature at PGA West/Estates California West ...
# 9       Signature at PGA West/Estates California West ...
# 10      Signature at PGA West/Estates California West ...
# 11                        Codorniz at La Quinta RJT Homes
# 12                        Codorniz at La Quinta RJT Homes
# 13                        Codorniz at La Quinta RJT Homes
# 14                        Codorniz at La Quinta RJT Homes
# 15                        Codorniz at La Quinta RJT Homes
# ...
